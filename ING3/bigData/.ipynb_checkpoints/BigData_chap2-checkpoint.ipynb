# %%
import numpy as np
import pandas as pd
import re
import json

movies = pd.read_csv("tmdb_5000_credits.csv")
acters = movies[['cast']]
actersls = acters['cast'].tolist()

# %%
collections = []
oneCollection = []
for i in actersls:
    ac_json = json.loads(i)
    for j in ac_json:
        oneCollection.append(j['name'])
    collections.append(oneCollection)
    oneCollection = []

data = [['yo', 'hei']]
j = 1
relationDf = pd.DataFrame(data, columns=['title', 'acter'])
for index,i in enumerate(collections):
    df = pd.DataFrame({'acter': i})
    df['title'] = movies['title'][index]
    relationDf = relationDf.append(df)
relationDf
# Out:
#                      acter                      title
# 0                      hei                         yo
# 0          Sam Worthington                     Avatar
# 1              Zoe Saldana                     Avatar
# 2         Sigourney Weaver                     Avatar
# 3             Stephen Lang                     Avatar
# 4       Michelle Rodriguez                     Avatar
# 5          Giovanni Ribisi                     Avatar
# 6         Joel David Moore                     Avatar
# 7              CCH Pounder                     Avatar
# 8                Wes Studi                     Avatar
# 9               Laz Alonso                     Avatar
# 10              Dileep Rao                     Avatar
# 11             Matt Gerald                     Avatar
# 12      Sean Anthony Moran                     Avatar
# 13             Jason Whyte                     Avatar
# 14          Scott Lawrence                     Avatar
# 15           Kelly Kilgour                     Avatar
# 16      James Patrick Pitt                     Avatar
# 17     Sean Patrick Murphy                     Avatar
# 18            Peter Dillon                     Avatar
# 19            Kevin Dorman                     Avatar
# 20        Kelson Henderson                     Avatar
# 21          David Van Horn                     Avatar
# 22            Jacob Tomuri                     Avatar
# 23    Michael Blain-Rozgay                     Avatar
# 24               Jon Curry                     Avatar
# 25             Luke Hawker                     Avatar
# 26           Woody Schultz                     Avatar
# 27            Peter Mensah                     Avatar
# 28               Sonia Yee                     Avatar
# ..                     ...                        ...
# 2          Peter Marquardt                El Mariachi
# 3          Reinol Martinez                El Mariachi
# 4             Ramiro Gomez                El Mariachi
# 5           Consuelo Gómez                El Mariachi
# 6              Juan García                El Mariachi
# 0             Edward Burns                  Newlyweds
# 1              Kerry Bishé                  Newlyweds
# 2          Marsha Dietlein                  Newlyweds
# 3       Caitlin Fitzgerald                  Newlyweds
# 4          Daniella Pineda                  Newlyweds
# 0              Eric Mabius  Signed, Sealed, Delivered
# 1            Kristin Booth  Signed, Sealed, Delivered
# 2             Crystal Lowe  Signed, Sealed, Delivered
# 3          Geoff Gustafson  Signed, Sealed, Delivered
# 4   Benjamin Hollingsworth  Signed, Sealed, Delivered
# 5            Laci J Mailey  Signed, Sealed, Delivered
# 6            Daphne Zuniga  Signed, Sealed, Delivered
# 0            Daniel Henney           Shanghai Calling
# 1              Eliza Coupe           Shanghai Calling
# 2              Bill Paxton           Shanghai Calling
# 3                Alan Ruck           Shanghai Calling
# 4               Zhu Shimao           Shanghai Calling
# 0           Drew Barrymore          My Date with Drew
# 1         Brian Herzlinger          My Date with Drew
# 2            Corey Feldman          My Date with Drew
# 3             Eric Roberts          My Date with Drew
# 4            Griffin Dunne          My Date with Drew
# 5        Samuel L. Jackson          My Date with Drew
# 6             Matt LeBlanc          My Date with Drew
# 7              Bill D'Elia          My Date with Drew
#
# [106258 rows x 2 columns]

# %%
relationDf.index = pd.RangeIndex(len(relationDf.index))
relationDf.drop(relationDf.index[0], inplace=True)
relationDf.head(10)
# Out:
#                  acter   title
# 1          Zoe Saldana  Avatar
# 2     Sigourney Weaver  Avatar
# 3         Stephen Lang  Avatar
# 4   Michelle Rodriguez  Avatar
# 5      Giovanni Ribisi  Avatar
# 6     Joel David Moore  Avatar
# 7          CCH Pounder  Avatar
# 8            Wes Studi  Avatar
# 9           Laz Alonso  Avatar
# 10          Dileep Rao  Avatar

# %%
relationDf.to_csv("relationDf.csv")

# %%
df = pd.read_csv("relationDf.csv")

# Exemple
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df1 = df.loc[df['title']=='Avatar']
# 54201 acters
#df.acter.unique()
# 4757 films
#print(len(df.title.unique()))

freq = df.groupby('acter').count()
freq = freq.loc[freq['title'] >= 30].sort_values(by=['title'], ascending=[False])

#Construction of a grand acter dict
acterDict = freq.to_dict('index')
print(acterDict.get('Alec Baldwin').get('title'))

#acterDict
#print(acterDict)
#freq
# print(df.title.unique())
#testG = df[(df['title']=='Red Dragon') | (df['title']=='Broken Arrow') | (df['title']=='The Doors')]
#testG = df[(df['acter']=='Frank Whaley')]
#testG
# Out:
# 39

# %%
# Construction of network
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib notebook
G = nx.Graph()

def extractionActers(G,df):
#     acters = df[df['title']=='Avatar']['acter']
#     addEdgeForOneFilm(G,acters.tolist())
    for i in df.title.unique():
        acters = df.loc[df['title'] == i]
        addEdgeForOneFilm(G,acters['acter'].tolist())

def addEdgeForOneFilm(G, acters):
    for i,a in enumerate(acters):
        for j in range(i+1, len(acters)):
            #print("add edge for " + a + " at pos " + str(i) + " and " + acters[j] + " at pos " + str(j))
            if G.has_edge(a, acters[j]):
                G[a][acters[j]]['weight'] += 0.5
            else:
                G.add_edge(a, acters[j], weight=0.1)

            
# If u want to draw all the data, replace here testG => df
extractionActers(G, testG)

pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=50)

# edges
#nx.draw_networkx_edges(G, pos, edges=G.edges(), width=weights)
nx.draw_networkx_edges(G, pos, edges=G.edges(), width=weights, alpha=0.1, edge_color='b')

# labels
nx.draw_networkx_labels(G, pos, font_size=6, font_family='sans-serif')

plt.subplots(figsize=(20,20))
plt.axis('off')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="1999.9999566511683">
