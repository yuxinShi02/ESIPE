# %%
import numpy as np
import pandas as pd
import re
import json

movies = pd.read_csv("tmdb_5000_credits.csv")
acters = movies[['cast']]
actersls = acters['cast'].tolist()

# %%
collections = []
oneCollection = []
for i in actersls:
    ac_json = json.loads(i)
    for j in ac_json:
        oneCollection.append(j['name'])
    collections.append(oneCollection)
    oneCollection = []

data = [['yo', 'hei']]
j = 1
relationDf = pd.DataFrame(data, columns=['title', 'acter'])
for index,i in enumerate(collections):
    df = pd.DataFrame({'acter': i})
    df['title'] = movies['title'][index]
    relationDf = relationDf.append(df)
relationDf
# Out:
#                      acter                      title
# 0                      hei                         yo
# 0          Sam Worthington                     Avatar
# 1              Zoe Saldana                     Avatar
# 2         Sigourney Weaver                     Avatar
# 3             Stephen Lang                     Avatar
# 4       Michelle Rodriguez                     Avatar
# 5          Giovanni Ribisi                     Avatar
# 6         Joel David Moore                     Avatar
# 7              CCH Pounder                     Avatar
# 8                Wes Studi                     Avatar
# 9               Laz Alonso                     Avatar
# 10              Dileep Rao                     Avatar
# 11             Matt Gerald                     Avatar
# 12      Sean Anthony Moran                     Avatar
# 13             Jason Whyte                     Avatar
# 14          Scott Lawrence                     Avatar
# 15           Kelly Kilgour                     Avatar
# 16      James Patrick Pitt                     Avatar
# 17     Sean Patrick Murphy                     Avatar
# 18            Peter Dillon                     Avatar
# 19            Kevin Dorman                     Avatar
# 20        Kelson Henderson                     Avatar
# 21          David Van Horn                     Avatar
# 22            Jacob Tomuri                     Avatar
# 23    Michael Blain-Rozgay                     Avatar
# 24               Jon Curry                     Avatar
# 25             Luke Hawker                     Avatar
# 26           Woody Schultz                     Avatar
# 27            Peter Mensah                     Avatar
# 28               Sonia Yee                     Avatar
# ..                     ...                        ...
# 2          Peter Marquardt                El Mariachi
# 3          Reinol Martinez                El Mariachi
# 4             Ramiro Gomez                El Mariachi
# 5           Consuelo Gómez                El Mariachi
# 6              Juan García                El Mariachi
# 0             Edward Burns                  Newlyweds
# 1              Kerry Bishé                  Newlyweds
# 2          Marsha Dietlein                  Newlyweds
# 3       Caitlin Fitzgerald                  Newlyweds
# 4          Daniella Pineda                  Newlyweds
# 0              Eric Mabius  Signed, Sealed, Delivered
# 1            Kristin Booth  Signed, Sealed, Delivered
# 2             Crystal Lowe  Signed, Sealed, Delivered
# 3          Geoff Gustafson  Signed, Sealed, Delivered
# 4   Benjamin Hollingsworth  Signed, Sealed, Delivered
# 5            Laci J Mailey  Signed, Sealed, Delivered
# 6            Daphne Zuniga  Signed, Sealed, Delivered
# 0            Daniel Henney           Shanghai Calling
# 1              Eliza Coupe           Shanghai Calling
# 2              Bill Paxton           Shanghai Calling
# 3                Alan Ruck           Shanghai Calling
# 4               Zhu Shimao           Shanghai Calling
# 0           Drew Barrymore          My Date with Drew
# 1         Brian Herzlinger          My Date with Drew
# 2            Corey Feldman          My Date with Drew
# 3             Eric Roberts          My Date with Drew
# 4            Griffin Dunne          My Date with Drew
# 5        Samuel L. Jackson          My Date with Drew
# 6             Matt LeBlanc          My Date with Drew
# 7              Bill D'Elia          My Date with Drew
#
# [106258 rows x 2 columns]

# %%
relationDf.index = pd.RangeIndex(len(relationDf.index))
relationDf.drop(relationDf.index[0], inplace=True)
relationDf.head(10)
# Out:
#                  acter   title
# 1      Sam Worthington  Avatar
# 2          Zoe Saldana  Avatar
# 3     Sigourney Weaver  Avatar
# 4         Stephen Lang  Avatar
# 5   Michelle Rodriguez  Avatar
# 6      Giovanni Ribisi  Avatar
# 7     Joel David Moore  Avatar
# 8          CCH Pounder  Avatar
# 9            Wes Studi  Avatar
# 10          Laz Alonso  Avatar

# %%
relationDf.to_csv("relationDf.csv")

# %%
df = pd.read_csv("relationDf.csv")

# Exemple
df.drop(['Unnamed: 0'], axis=1, inplace=True)
#df1 = df.loc[df['title']=='Avatar']
# 54201 acters
print("There are : " + str(len(df.acter.unique())) + " acters.")
# 4757 films
print("There are : " + str(len(df.title.unique())) + " films.")

# Calculate acters frequence in all films
freq = df.groupby('acter').count().sort_values(by=['title'], ascending=[False])
freq
# Out:
# There are : 54201 acters.
# There are : 4757 films.
#                         title
# acter
# Samuel L. Jackson          67
# Robert De Niro             57
# Bruce Willis               51
# Matt Damon                 48
# Morgan Freeman             46
# Steve Buscemi              43
# Liam Neeson                41
# Johnny Depp                40
# Owen Wilson                40
# Nicolas Cage               39
# John Goodman               39
# Alec Baldwin               39
# Stanley Tucci              38
# Willem Dafoe               38
# Jim Broadbent              38
# Brad Pitt                  38
# Paul Giamatti              37
# Will Ferrell               37
# Richard Jenkins            36
# Susan Sarandon             36
# J.K. Simmons               35
# Bill Murray                35
# Keith David                35
# Christopher Walken         35
# Paul Rudd                  34
# George Clooney             34
# Anthony Hopkins            34
# Jack Black                 34
# David Koechner             34
# Robin Williams             34
# ...                       ...
# Jack Krizmanich             1
# Jack Kyle                   1
# Jack LaLanne                1
# Jack Landry                 1
# Jack Larson                 1
# Jack Laskey                 1
# Jack Laufer                 1
# Jack Lilley                 1
# Jack Henry Robbins          1
# Jack Hallett                1
# Jack Guzman                 1
# Jack Griffo                 1
# Jack Dalton                 1
# Jack De Sena                1
# Jack Del Rio                1
# Jack Depp                   1
# Jack Devnarain              1
# Jack Dodson                 1
# Jack Donner                 1
# Jack Doolan                 1
# Jack Douglas Patterson      1
# Jack Egan                   1
# Jack Ferver                 1
# Jack Fitzstephens           1
# Jack Foley                  1
# Jack Gargan                 1
# Jack George                 1
# Jack Ging                   1
# Jack Gould                  1
# 徐帆                          1
#
# [54201 rows x 1 columns]

# %%
# Select the acters who plays at least 10 films
freq = freq.loc[freq['title'] >= 10].sort_values(by=['title'], ascending=[False])
# Restructure freq in a correct format
freq['acter'] = freq.index
freq.index = pd.RangeIndex(len(freq.index))
freq
# Out:
#       title                acter
# 0        67    Samuel L. Jackson
# 1        57       Robert De Niro
# 2        51         Bruce Willis
# 3        48           Matt Damon
# 4        46       Morgan Freeman
# 5        43        Steve Buscemi
# 6        41          Liam Neeson
# 7        40          Johnny Depp
# 8        40          Owen Wilson
# 9        39         Alec Baldwin
# 10       39         John Goodman
# 11       39         Nicolas Cage
# 12       38        Stanley Tucci
# 13       38         Willem Dafoe
# 14       38        Jim Broadbent
# 15       38            Brad Pitt
# 16       37        Paul Giamatti
# 17       37         Will Ferrell
# 18       36       Susan Sarandon
# 19       36      Richard Jenkins
# 20       35         J.K. Simmons
# 21       35          Keith David
# 22       35   Christopher Walken
# 23       35          Bill Murray
# 24       34       Robin Williams
# 25       34          Justin Long
# 26       34         Ben Kingsley
# 27       34      Michael Shannon
# 28       34           Bill Hader
# 29       34       David Koechner
# ...     ...                  ...
# 1301     10           Lynn Cohen
# 1302     10    Patricia Arquette
# 1303     10         Jon Bernthal
# 1304     10     Bridgette Wilson
# 1305     10         Rick Overton
# 1306     10        Alexis Bledel
# 1307     10           Mel Brooks
# 1308     10       Peter McRobbie
# 1309     10         Jon Abrahams
# 1310     10         Gina Gershon
# 1311     10          Ben Chaplin
# 1312     10      AnnaSophia Robb
# 1313     10        Eric Bogosian
# 1314     10         Philip Bosco
# 1315     10       Megan Mullally
# 1316     10         Sanaa Lathan
# 1317     10             Bai Ling
# 1318     10       Olga Kurylenko
# 1319     10    Eddie Kaye Thomas
# 1320     10      Adrian Martinez
# 1321     10     Alexander Siddig
# 1322     10       Andre Braugher
# 1323     10            Mark Addy
# 1324     10  Chad Michael Murray
# 1325     10    Deirdre O'Connell
# 1326     10             Lee Pace
# 1327     10            Omar Epps
# 1328     10        Jimmi Simpson
# 1329     10           Joy Bryant
# 1330     10         James Gammon
#
# [1331 rows x 2 columns]

# %%
# Select the acters who plays at least 10 films and converts thems into a list
famousActers = freq['acter'].tolist()

# Construct my points of acters
testG = df[(df['acter']).isin(famousActers)]
testG.sort_values(by=['acter'])
testG
# Out:
#                      acter                                     title
# 0          Sam Worthington                                    Avatar
# 1              Zoe Saldana                                    Avatar
# 2         Sigourney Weaver                                    Avatar
# 3             Stephen Lang                                    Avatar
# 4       Michelle Rodriguez                                    Avatar
# 5          Giovanni Ribisi                                    Avatar
# 83             Johnny Depp  Pirates of the Caribbean: At World's End
# 84           Orlando Bloom  Pirates of the Caribbean: At World's End
# 85         Keira Knightley  Pirates of the Caribbean: At World's End
# 86       Stellan Skarsgård  Pirates of the Caribbean: At World's End
# 88              Bill Nighy  Pirates of the Caribbean: At World's End
# 89           Geoffrey Rush  Pirates of the Caribbean: At World's End
# 91           Kevin McNally  Pirates of the Caribbean: At World's End
# 92           Tom Hollander  Pirates of the Caribbean: At World's End
# 93           Naomie Harris  Pirates of the Caribbean: At World's End
# 94          Jonathan Pryce  Pirates of the Caribbean: At World's End
# 97         Mackenzie Crook  Pirates of the Caribbean: At World's End
# 100          Martin Klebba  Pirates of the Caribbean: At World's End
# 117           Daniel Craig                                   Spectre
# 118        Christoph Waltz                                   Spectre
# 120          Ralph Fiennes                                   Spectre
# 121        Monica Bellucci                                   Spectre
# 122            Ben Whishaw                                   Spectre
# 123          Naomie Harris                                   Spectre
# 194             Judi Dench                                   Spectre
# 200         Christian Bale                     The Dark Knight Rises
# 201          Michael Caine                     The Dark Knight Rises
# 202            Gary Oldman                     The Dark Knight Rises
# 203          Anne Hathaway                     The Dark Knight Rises
# 204              Tom Hardy                     The Dark Knight Rises
# ...                    ...                                       ...
# 105596      Susan Sarandon            The Past Is a Grotesque Animal
# 105599       Mark Margolis                                        Pi
# 105615          Jack McGee               I Love You, Don't Touch Me!
# 105655       Anna Kendrick                           Happy Christmas
# 105656     Melanie Lynskey                           Happy Christmas
# 105657         Mark Webber                           Happy Christmas
# 105703      Kevin Corrigan                     Supporting Characters
# 105712          Doug Jones                                  Absentia
# 105726        Edward Burns                     The Brothers McMullen
# 105792  Laurence Fishburne                                The Signal
# 105794           Lin Shaye                                The Signal
# 105821       Norman Reedus                      The Image Revolution
# 105866           Jon Gries                              A True Story
# 105990         Jason Mewes                                    Clerks
# 105991         Kevin Smith                                    Clerks
# 106021       Aaron Eckhart                     In the Company of Men
# 106023         Matt Malloy                     In the Company of Men
# 106060        Stephen Lang                                  Backmask
# 106099       Andrea Martin                          Breaking Upwards
# 106103      Olivia Thirlby                          Breaking Upwards
# 106112          Lucas Till                  All Superheroes Must Die
# 106113         James Remar                  All Superheroes Must Die
# 106128          Nick Nolte                                     Clean
# 106203            Lucy Liu                                      Bang
# 106232        Edward Burns                                 Newlyweds
# 106239        Crystal Lowe                 Signed, Sealed, Delivered
# 106246         Bill Paxton                          Shanghai Calling
# 106249      Drew Barrymore                         My Date with Drew
# 106252        Eric Roberts                         My Date with Drew
# 106254   Samuel L. Jackson                         My Date with Drew
#
# [21853 rows x 2 columns]

# %%
# Construction of network
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib notebook
G = nx.Graph()

def extractionActers(G,df):
#     acters = df[df['title']=='Avatar']['acter']
#     addEdgeForOneFilm(G,acters.tolist())
    for i in df.title.unique():
        acters = df.loc[df['title'] == i]
        addEdgeForOneFilm(G,acters['acter'].tolist())

def addEdgeForOneFilm(G, acters):
    for i,a in enumerate(acters):
        for j in range(i+1, len(acters)):
            #print("add edge for " + a + " at pos " + str(i) + " and " + acters[j] + " at pos " + str(j))
            if G.has_edge(a, acters[j]):
                G[a][acters[j]]['weight'] += 0.001
            else:
                G.add_edge(a, acters[j], weight=0.1)

            
# If u want to draw all the data, replace here testG => df
# But I tried to use all data, but it doesn't work at all.
extractionActers(G, testG)

pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=0.1)

# edges
nx.draw_networkx_edges(G, pos, edges=G.edges(), alpha=0.1, edge_color='b')

labels = {}
for node in G.nodes():
    if len(G.edges(node)) > 60:
        labels[node] = node
# labels of points
nx.draw(G, with_labels=False)
nx.draw_networkx_labels(G, pos, labels, font_size=6, font_family='sans-serif')

plt.subplots(figsize=(40,40))
plt.axis('off')
plt.show()
plt.savefig("Graph_by_acters.png", format="PNG")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="3999.9999133023366">
